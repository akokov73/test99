# %% [markdown]
# <a href="https://colab.research.google.com/github/akokov73/test99/blob/main/SQLite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import  drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !cp /content/drive/MyDrive/example.db /content/example.db

# %%
!

# %%
 ! pip3 install requests # импортируем модуль requests
 ! pip3 install beautifulsoup4 
! pip install cfscrape
! pip3 list
import os
import time
import random
import requests as rq
import cfscrape
from bs4 import BeautifulSoup

# %%
url = 'https://med-books.by/'

# %%
Titles_articles = []
scraper = cfscrape.create_scraper()  # returns a CloudflareScraper instance
page = scraper.get(url).content  # => "<!DOCTYPE html><html><head>..."
soup = BeautifulSoup(page,"html.parser")
for a_tag in soup.find_all("a"):
    if 'istorii' in a_tag['href']:
        if not 'https' in a_tag['href']:
            print(a_tag['href'])
            Titles_articles.append(a_tag['href']) 
print(Titles_articles)
# Out:
# /istorii_akusherstvo/
# /istorii_allergologiya-immunologiya/
# /istorii_angiologiya/
# /istorii_vnutrennie-bolezni/
# /istorii_gastroenterologiya/
# /istorii_gematologiya/
# /istorii_ginekologiya/
# /istorii_dermatovenerologiya/
# /istorii_infekcionnye_bolezni/
# /istorii_kardiologiya/
# /istorii_narkologiya/
# /istorii_nevrologiya/
# /istorii_nefrologiya/
# /istorii_onkologiya/
# /istorii_otorinolaringologiya/
# /istorii_oftalmologiya/
# /istorii_pediatriya/
# /istorii_pofessionalnie_bilezni/
# /istorii_psixiatriya/
# /istorii_pulmonologiya/
# /istorii_revmatologiya/
# /istorii_stomatologiya/
# /istorii_sudebnaya-medicina/
# /istorii_travmatologiya_ortopediya/
# /istorii_urologiya/
# /istorii_ftiziatriya/
# /istorii_hirurgiya/
# /istorii_endokrinologiya/
# ...

# %%
print(Titles_articles[0][9:-1])
# Out:
# akusherstvo

# %%
conn = sqlite3.connect('example.db')
#Creating a cursor object using the cursor() method
cursor = conn.cursor()#Retrieving specific records using the where clause
 
for art_url in Titles_articles: 
    new_art_url = url[:-1] + art_url
    time.sleep(random.randint(3,4))
    scraper = cfscrape.create_scraper()  # returns a CloudflareScraper instance
    page = scraper.get(new_art_url).content  # => "<!DOCTYPE html><html><head>..."
    soup = BeautifulSoup(page,"html.parser")
    Titles = []
    name_of_file = art_url[1:-1] + '.txt'
    my_file = open(name_of_file, 'w')
    for tag in soup.find_all("div",{"class":"all"}): 
        for tag_1 in tag.find_all("h2",{"class":"title"}): 
            for tag_2 in tag.find_all("a"): 
                url_child = tag_2['href']
                if 'html' in url_child:
                    # print (url_child )
                    # print(tag_2['href'])
                    number_str = len(Titles)+1
                    my_file.write(str(number_str) +'\n')                
                    my_file.write(tag_2['href'])
                    my_file.write('\n')                
                    Titles.append(tag_2['href'])
                    time.sleep(random.randint(3,4))
                    page_child = scraper.get(url_child).content  # => "<!DOCTYPE html><html><head>..."
                    soup_child = BeautifulSoup(page_child,"html.parser")    
                    for tag_3 in soup_child.find_all("div",{"class":"news"}):                 
                        my_file.write(tag_3.text)

                        l_br = tag_3.text.find("«",0)
                        r_br = tag_3.text.find("»",l_br)
                        if l_br > 0 and r_br > 0: 
                            article_header = tag_3.text[l_br+1:r_br]                        
                            article_text = tag_3.text[r_br+1:]
                        else:
                            article_header = art_url[9:-1]
                            article_text = tag_3.text
                        cursor.execute("INSERT INTO MED_TEXTS(TITLE, TITLE_EN, SOURCE, TEXT1, TEXT2) VALUES (?, ?, ?, ?,?)", (article_header, art_url[9:-1], new_art_url, name_of_file, article_text ))

                        print(tag_3.text)
                    my_file.write('\n')
                    
    # print(Titles)
    my_file.close()
conn.commit()       
print("Records inserted........")
# Closing the connection
conn.close()

# %%
conn = sqlite3.connect('example.db')
cursor = conn.cursor()#Re
cursor.execute("SELECT * from MED_TEXTS")    
result = cursor.fetchone();
conn.commit()       
print(result)
print("Records inserted........")
# Closing the connection
conn.close()
# Out:
# (1, 'https://med-books.by/istorii_akusherstvo/', 'I период I срочных родов', 'akusherstvo', None, None, None, None, 'istorii_akusherstvo.txt', 'ПАСПОРТНАЯ ЧАСТЬВозраст:20 летМесто работы (учебы):ДомохозяйкаДата поступления:5.01.04.Диагноз при поступлении:I период I срочных родовДата курации:06.01.04Клинический диагноз: I период I срочных родовОсложнения: Разрыв задней стенки влагалища внутренний,Эпизиотомия-ррафия 2 швамиЖАЛОБЫНа момент курации жалоб не предъявляла.АНАМНЕЗ НАСТОЯЩЕГО ЗАБОЛЕВАНИЯНастоящая беременность первая, желаннаяАНАМНЕЗ ЖИЗНИСоциальный анамнез.Родилась в 1983 году. Росла и развивалась нормально в соответствии с паспортным возрастом. В школу пошла с 7 лет. Учеба давалась легко. Образование среднее. Не работает. Профессиональных вредностей нет. Вредные привычки: курение, употребление алкоголя и наркотиков отрицает. Питание регулярное, полноценное.Перенесенные заболевания.Гепатит, туберкулез, венерические болезни отрицает. Переливаний крови или ее компонентов не был
# ...

# %%
text_hist = result[9]
print(text_hist)
# Out:
# ПАСПОРТНАЯ ЧАСТЬВозраст:20 летМесто работы (учебы):ДомохозяйкаДата поступления:5.01.04.Диагноз при поступлении:I период I срочных родовДата курации:06.01.04Клинический диагноз: I период I срочных родовОсложнения: Разрыв задней стенки влагалища внутренний,Эпизиотомия-ррафия 2 швамиЖАЛОБЫНа момент курации жалоб не предъявляла.АНАМНЕЗ НАСТОЯЩЕГО ЗАБОЛЕВАНИЯНастоящая беременность первая, желаннаяАНАМНЕЗ ЖИЗНИСоциальный анамнез.Родилась в 1983 году. Росла и развивалась нормально в соответствии с паспортным возрастом. В школу пошла с 7 лет. Учеба давалась легко. Образование среднее. Не работает. Профессиональных вредностей нет. Вредные привычки: курение, употребление алкоголя и наркотиков отрицает. Питание регулярное, полноценное.Перенесенные заболевания.Гепатит, туберкулез, венерические болезни отрицает. Переливаний крови или ее компонентов не было.Менструальная функция.Менструации с 14 лет, установились сразу, цикл длится 21 дней. Менструации по 6 дней, обильные, безболезненные. Дата пос
# ...

# %%
print(article_header, art_url[9:-1], new_art_url, name_of_file, article_text )
# Out:
# I период I срочных родов akusherstvo https://med-books.by/istorii_akusherstvo/ istorii_akusherstvo.txt »ПАСПОРТНАЯ ЧАСТЬВозраст:20 летМесто работы (учебы):ДомохозяйкаДата поступления:5.01.04.Диагноз при поступлении:I период I срочных родовДата курации:06.01.04Клинический диагноз: I период I срочных родовОсложнения: Разрыв задней стенки влагалища внутренний,Эпизиотомия-ррафия 2 швамиЖАЛОБЫНа момент курации жалоб не предъявляла.АНАМНЕЗ НАСТОЯЩЕГО ЗАБОЛЕВАНИЯНастоящая беременность первая, желаннаяАНАМНЕЗ ЖИЗНИСоциальный анамнез.Родилась в 1983 году. Росла и развивалась нормально в соответствии с паспортным возрастом. В школу пошла с 7 лет. Учеба давалась легко. Образование среднее. Не работает. Профессиональных вредностей нет. Вредные привычки: курение, употребление алкоголя и наркотиков отрицает. Питание регулярное, полноценное.Перенесенные заболевания.Гепатит, туберкулез, венерические болезни отрицает. Переливаний крови или ее компонентов не было.Менструальная функция.Менструации с 14
# ...

# %%
pip install fdb

# %%
import fdb
import os.path 
hh = '/content/db.fdb'
con = fdb.create_database(dsn=hh,user='sysdba',password='masterkey',page_size=8192)

# %%
# !pwd
# Out:
# /content

# %%
import sqlite3
conn = sqlite3.connect('example.db')
cursor = conn.cursor()

#Doping EMPLOYEE table if already exists.
cursor.execute("DROP TABLE IF EXISTS MED_TEXTS")
#Creating table as per requirement
sql ='''CREATE TABLE MED_TEXTS(
ID INTEGER PRIMARY KEY AUTOINCREMENT,
SOURCE CHAR(200),
TITLE CHAR(200),
TITLE_EN CHAR(200),
FIELD1 INT,
FIELD2 CHAR(1),
FIELD3 FLOAT,
SEGMENTED_TEXT TEXT,
TEXT1 TEXT,
TEXT2 TEXT)'''
cursor.execute(sql)
print("Table created successfully........")
# Out:
# Table created successfully........

# %%
conn = sqlite3.connect('example.db')
#Creating a cursor object using the cursor() method
cursor = conn.cursor()#Retrieving specific records using the where clause
cursor.execute("SELECT SOURCE, TEXT2 from MED_TEXTS")    
result = cursor.fetchall();
for row in result:
        print(row[0],row[1])

conn.commit()
print("All records fetched........")
# Closing the connection
conn.close()

# %%
#Connecting to sqlite
conn = sqlite3.connect('example.db')
#Creating a cursor object using the cursor() method
cursor = conn.cursor()#Retrieving specific records using the where clause
# cursor.execute("SELECT * from EMPLOYEE WHERE AGE <23")    
cursor.execute("SELECT TEXT2 from MED_TEXTS")    
#Fetching 1st row from the table
# result = cursor.fetchone();
result = cursor.fetchall();
for row in result:
    str_hist = row[0]
    
    print(str_hist)
    # print(row[0])
conn.commit()
#Closing the connection
conn.close()
# Out:
# Скачать бесплатно историю болезни по хирургии, ангиологии: « Варикозная болезнь голени справа в бассейне БПВ II  формы,  голени и бедра слева в бассейне БПВ I формы, ХВН–0»Паспортные данные:Ф.И.О.   Возраст -  41                             дата рождения -  25.01.62.Место жительства -  .Место работы – Клинический диагноз:  Варикозная болезнь голени справа в бассейне БПВ II  формы, ХВН – 0.      Осложнения:   нет.Сопутствующие:  язва ДПК, миома матки, хронический тонзиллит ЖАЛОБЫ. Предъявляет жалобы на наличие расширенных вен, сосудистых звездочек на голени  справа, на голени и бедре слева.ANAMNESIS MORBI.  18 лет назад во время  третьей беременности во втором триместре  на голени справа и слева  появились телеангиэктазии, ретикулярный варикоз, примерно через 1 год после этого стали появляться  варикозно-расширенные вены на голени справа.  До поступления в клинику никакой медицинской помощи не оказывалось, лекарственные препараты не применялись. Направлена на лечение из  больницы на с
# ...

# %%
document = str_hist
text_words_frequencies = dd(int)
document_tokenized = document.split()
for word in document_tokenized:
     text_words_frequencies[word] += 1 / len(document_tokenized)
     sorted_frequency_table = sorted(text_words_frequencies.items(), 
                                    key=itemgetter(1), reverse=True)    
        
    #  for word, freq in sorted_frequency_table[:10]:
     for word, freq in sorted_frequency_table:
          print('\t'.join((word, str(freq))))
        
show_wordcloud_by_freq_dict(text_words_frequencies)
print(document)
# Out:
# Streaming output truncated to the last 5000 lines.
# сознании,	0.0004224757076468103
# контактен,	0.0004224757076468103
# адекватен,	0.0004224757076468103
# ориентирован	0.0004224757076468103
# месте	0.0004224757076468103
# времени.	0.0004224757076468103
# Общемозговых	0.0004224757076468103
# менингиальных	0.0004224757076468103
# симптомов	0.0004224757076468103
# LOCALIS.	0.0004224757076468103
# ослаблена	0.0004224757076468103
# стопы.	0.0004224757076468103
# сонных	0.0004224757076468103
# симметрична,	0.0004224757076468103
# шума	0.0004224757076468103
# Per	0.0004224757076468103
# rectum:	0.0004224757076468103
# образований	0.0004224757076468103
# высоте	0.0004224757076468103
# нет,	0.0004224757076468103
# исследование	0.0004224757076468103
# безболезненно.	0.0004224757076468103
# ПРЕДВАРИТЕЛЬНЫЙ	0.0004224757076468103
# ДИАГНОЗ.	0.0004224757076468103
# ходьбе;	0.0004224757076468103
# данных	0.0004224757076468103
# анамнеза	0.0004224757076468103
# первое	0.0004224757076468103
# ...

# %%
# !pip -qq install yargy --progress-bar off
# !pip -qq install pymorphy2 --progress-bar off
# !pip -qq install rusenttokenize --progress-bar off

import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download("punkt", quiet=True)
nltk.download("stopwords", quiet=True)
# Out:
# True

# %%
! pip3 install wordcloud

# %%
 # wordcloud stuff

import matplotlib.pyplot as plt
from wordcloud import WordCloud

def show_wordcloud_by_freq_dict(freq_dict):
    wordcloud = WordCloud()
    wordcloud.generate_from_frequencies(frequencies=freq_dict)
    plt.figure()
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
from collections import defaultdict as dd
from operator import itemgetter


# with open(LENTA_TEXTS_FN) as corpus_f:
with open('istorii.txt') as corpus_f:
    for document in corpus_f:

        text_words_frequencies = dd(int)
        
        document_tokenized = document.split()
        for word in document_tokenized:
            text_words_frequencies[word] += 1 / len(document_tokenized)

        sorted_frequency_table = sorted(text_words_frequencies.items(), 
                                        key=itemgetter(1), reverse=True)    
        
        for word, freq in sorted_frequency_table[:10]:
            print('\t'.join((word, str(freq))))
        
        show_wordcloud_by_freq_dict(text_words_frequencies)
        print(document)
        
        # proceed = input("proceed? ( [n] to refuse) : ")
        # if proceed.strip().lower() == "n":
        #     break

# %%
text_hist= "Скачать бесплатно историю болезни по хирургии, ангиологии: « Варикозная болезнь голени справа в бассейне БПВ II  формы,  голени и бедра слева в бассейне БПВ I формы, ХВН–0»Паспортные данные:Ф.И.О.   Возраст -  41                             дата рождения -  25.01.62.Место жительства -  .Место работы – Клинический диагноз:  Варикозная болезнь голени справа в бассейне БПВ II  формы, ХВН – 0.      Осложнения:   нет.Сопутствующие:  язва ДПК, миома матки, хронический тонз
варикозная болезнь голени и бедра слева в бассейне БПВ I формы, ХВН – 0. Назначено лечение: лазеротерапия, магнитотерапия, ЛФК, медикаментозная терапия:  детралекс, кислота аскорбиновая, тиклид, оперативное лечение – флебэктомия, склеротерапия. Выписана с исходом: выздоровление.Рекомендации: Эластическая компрессия оперированной нижней конечности в течении 2 месяцев. Детралекс по 2 таблетки в день 1 месяц. Возвышенное  положение для нижних конечностей на 15 минут 3-4 раза в день; самомассаж нижних конечностей в восходящем направлении.ЛИТЕРАТУРА.1.	Мазаев П.Н., Королюк И.П., Жуков Б.Н. Хроническая венозная недостаточность нижних конечностей. – М.: Медицина, 1987, 256 с., ил.2.	Машковский М.Д. Лекарственные средства. 14-е изд., перераб., испр. и доп.- М.: ООО «Издательство Новая Волна». 2000.3.	Покровский А.В. Клиническая ангиология. – М.: Медицина, 1979. – 368 с., с ил.4.	Репитников Е.А., Тихонравова Т.А., Кобцова Л.Ф. Реабилитация больных варикозным расширением вен нижних конечностей после флебэктомии.//Хирургия. – 1987. - № 6. – С.70-73.5.	Сердечно-сосудистая хирургия: руководство / В.И. Бураковский, Л.А. Бокерия и др.; Под ред. акад. АМН СССР В.И. Бураковского, проф. Л.А. Бокерия. – М.: Медицина, 1989. – 752 с.: ил.6.	Стойко Ю.М., Шайдаков Е.В., Гаврилов Е.К. XIV Всемирный конгресс флебологов – научно-практический форум на рубеже веков.//Вестник хирургии. – 2003. - № 1. – С.89-91.7.	Энциклопедия клинического обследования больного: Пер. с англ.- М.: Геотар Медицина, 1998.- 704 с."

# %%
l_br = text_hist.find("«",0)
print(l_br)
r_br = text_hist.find("»",l_br)
print(r_br)
print(text_hist[:l_br])
print(text_hist[l_br+1:r_br])
# Out:
# 59
# 171
# Скачать бесплатно историю болезни по хирургии, ангиологии:
#  Варикозная болезнь голени справа в бассейне БПВ II  формы,  голени и бедра слева в бассейне БПВ I формы, ХВН–0

# %%
tt = text_hist.replace("Скачать бесплатно историю болезни по хирургии, ангиологии: ",'')
print(tt)
# Out:
# « Варикозная болезнь голени справа в бассейне БПВ II  формы,  голени и бедра слева в бассейне БПВ I формы, ХВН–0»Паспортные данные:Ф.И.О.   Возраст -  41                             дата рождения -  25.01.62.Место жительства -  .Место работы – Клинический диагноз:  Варикозная болезнь голени справа в бассейне БПВ II  формы, ХВН – 0.      Осложнения:   нет.Сопутствующие:  язва ДПК, миома матки, хронический тонзиллит ЖАЛОБЫ. Предъявляет жалобы на наличие расширенных вен, сосудистых звездочек на голени  справа, на голени и бедре слева.ANAMNESIS MORBI.  18 лет назад во время  третьей беременности во втором триместре  на голени справа и слева  появились телеангиэктазии, ретикулярный варикоз, примерно через 1 год после этого стали появляться  варикозно-расширенные вены на голени справа.  До поступления в клинику никакой медицинской помощи не оказывалось, лекарственные препараты не применялись. Направлена на лечение из  больницы на ст. Новокузнецк с диагнозом варикозная болезнь нижних конечн
# ...

# %%
 art_url = Titles_articles[0][1:-1]
print(art_url)

# %%
colours = ["green","red", "yellow"]
for idx, intem in enumerate(colours):
    print(idx, intem)
# Out:
# 0 green
# 1 red
# 2 yellow
